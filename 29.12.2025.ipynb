# %% [markdown]
# ### Boolean

# %%
# true or false - output for boolean exp

print(1 < 2)
# Out:
# True

# %%
print(bool('besant'))
# Out:
# True

# %%
print(bool(13))
# Out:
# True

# %%
print(bool())
# Out:
# False

# %%
print(bool(0))
# Out:
# False

# %%
print(bool(None))
# Out:
# False

# %% [markdown]
# ### Operators

# %%
print(10+2)
# Out:
# 12

# %%
a = 10 + 2
print(a)
# Out:
# 12

# %% [markdown]
# - arthmetic
# - assignment
# - comparison
# - logical
# - identity
# - membership
# - bitwise

# %%
x = 10
y = 5

print(x/y) # division - returns a float value
print(x//y) # floor division - returns an integer
# Out:
# 2.0
# 2

# %%
print(x ** y)
# Out:
# 100000

# %%
# identity operators 
# is, is not

x = [1,2,3]
y = [1,2,3]

print(x is y) #identity operator
print(x == y) # comparison operator
# Out:
# False
# True

# %%
x = [1,2,3]
y = x
    
print(x is y)
# Out:
# True

# %% [markdown]
# ### Operator precedence (order of operation)

# %%
print(5 + 4 - 7 + 3)

# addition and subtraction has equal precedence, so we need to solve the equ from left to right
# (5+4) -> 9 - 7 + 3
#  ( 9-7) -> 2 + 3
# 5
# Out:
# 5

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print( 3 + 2 * 5)
# Out:
# 13

# %% [markdown]
# ## List

# %% [markdown]
# - it is used to store multiple values in single variable
# - mutable
# - heterogeneous set of data can be stored
# - enclosed between [ ]
# - indexing can be done
# - ordered collection of items
# - allows duplicates

# %%
lst = ['python', 'ai','java']

# %%
type(lst)
# Out:
# list

# %%
lst[0] # indexing
# Out:
# 'python'

# %%
lst = ['python', 'ai', 'java', 'python']

# %%
lst
# Out:
# ['python', 'ai', 'java', 'python']

# %%
len(lst)
# Out:
# 4

# %%
lst_1 = [12,33,55]

# %%
lst_1
# Out:
# [12, 33, 55]

# %%
lst_2 = ['besant', 7, "coaching", True]

# %%
type(lst_2)
# Out:
# list

# %%
# list() constructor - to create a list

my_list = list(('frontend','backend'))
type(my_list)
# Out:
# list

# %%
# accessing items
lst
# Out:
# ['python', 'ai', 'java', 'python']

# %%
lst[1] # positive indexing 
# always starts from 0 from left
# Out:
# 'ai'

# %%
# negative indexing
# starts from -1 for the last item on the list
lst[-1]
# Out:
# 'python'

# %%
# range of indexes

lst[0:2]

# in the range, end of the range is not included - so it fetches value having index 0, 1 only
# Out:
# ['python', 'ai']

# %%
lst[0:3]
# Out:
# ['python', 'ai', 'java']

# %%
lst[:3]
# Out:
# ['python', 'ai', 'java']

# %%
lst[1:]
# Out:
# ['ai', 'java', 'python']

# %%
# replacing values in the list

lst
# Out:
# ['python', 'ai', 'java', 'python']

# %%
lst[3] = 'c++'

# %%
lst
# Out:
# ['python', 'ai', 'java', 'c++']

# %%
# insert items in the list - you can specify where you want to insert the value

lst.insert(3, 'c')

# %%
lst
# Out:
# ['python', 'ai', 'java', 'c', 'c++']

# %%
# append items to the list - adds the value to the end of the list

lst.append('testing')

# %%
lst
# Out:
# ['python', 'ai', 'java', 'c', 'c++', 'testing']

# %%
# extend 

lst_1
# Out:
# [12, 33, 55]

# %%
lst.extend(lst_1)

# %%
lst
# Out:
# ['python', 'ai', 'java', 'c', 'c++', 'testing', 12, 33, 55]

# %%
# removing an item in the list - to remove using the value itself

lst.remove(12)

# %%
lst
# Out:
# ['python', 'ai', 'java', 'c', 'c++', 'testing', 33, 55]

# %%
lst_3 = ['python', 'ai', 'gen-ai', 'gen-ai']
lst_3
# Out:
# ['python', 'ai', 'gen-ai', 'gen-ai']

# %%
lst_3.remove('gen-ai')

# %%
lst_3
# Out:
# ['python', 'ai', 'gen-ai']

# %%
# pop - to remove using the specified index

lst.pop(3)
# Out:
# 'c'

# %%
lst
# Out:
# ['python', 'ai', 'java', 'c++', 'testing', 33, 55]

# %%
lst.pop() # always removes the last item
# Out:
# 55

# %%
lst
# Out:
# ['python', 'ai', 'java', 'c++', 'testing', 33]
