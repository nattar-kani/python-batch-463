# %% [markdown]
# ## Variables

# %%
# creating and assigning a value to the variable

x = 2

# %%
x
# Out:
# 2

# %%
y = 3
z = 4
a = 5

# %%
z
# Out:
# 4

# %%
print(x+y+z)
# Out:
# 9

# %%
# create and assign many values to multiple varaibles
x, y, z = "Java", "Python", "C++"

# %%
print(x)
# Out:
# Java

# %%
y
# Out:
# 'Python'

# %%
z
# Out:
# 'C++'

# %%
x
y
z
# Out:
# 'C++'

# %%
print(x,y,z)
# Out:
# Java Python C++

# %%
# assign one value to multiple variables

a = b = 3.0

# %%
a
# Out:
# 3.0

# %%
b
# Out:
# 3.0

# %%
# to unpack a collection

lang = ["python", "java", "c++"] # collection created
L1, L2, L3 = lang

# %%
L1
# Out:
# 'python'

# %%
L2
# Out:
# 'java'

# %%
L3
# Out:
# 'c++'

# %%
x = 10
y = "John"
print(x+y) #try this
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14408\2796848411.py in <module>
#       1 x = 10
#       2 y = "John"
# ----> 3 print(x+y) #try this
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# ## Data types

# %% [markdown]
# ### Python numbers

# %%
x = 2501
y = 6.4
z = 4j

# %%
type(x)
# Out:
# int

# %%
type(y)
# Out:
# float

# %%
type(z)
# Out:
# complex

# %%
# typecasting - explicit type conversion
# convert int to float
a = float(x)

# %%
print(a)
print(type(a))
# Out:
# 2501.0
# <class 'float'>

# %%
# convert float to int
b = int(y)
print(b)
print(type(b))
# Out:
# 6
# <class 'int'>

# %%
# convert int to complex
c = complex(x)
print(c)
print(type(c))
# Out:
# (2501+0j)
# <class 'complex'>

# %%
x = 24e2

# %%
type(x)
# Out:
# float

# %%
y = 3 + 8j

# %%
type(y)
# Out:
# complex

# %%
# type casting - implicit type conversion

a = 5
print(type(a))
# Out:
# <class 'int'>

# %%
b = 2.0
print(type(b))
# Out:
# <class 'float'>

# %%
c = a + b
print(c)
print(type(c))
# Out:
# 7.0
# <class 'float'>

# %%
d = a*b
print(d)
print(type(d))
# Out:
# 10.0
# <class 'float'>

# %% [markdown]
# ### Strings

# %%
a = "hello"
b = 'hello'
print(type(a))
print(type(b))
# Out:
# <class 'str'>
# <class 'str'>

# %%
print("We are learning Python")
# Out:
# We are learning Python

# %%
print("We're learning python")
# Out:
# We're learning python

# %%
print("We are learning 'python'")
# Out:
# We are learning 'python'

# %%
print('we are learning "python"')
# Out:
# we are learning "python"

# %%
# multiline strings / sentences

desc = """we are learning python
this course is for 20 hours"""

# %%
#check string

print("hours" in desc)
# Out:
# True

# %%
print("hou" in desc)
# Out:
# True

# %%
desc
# Out:
# 'we are learning python\nthis course is for 20 hours'

# %%
#considering strings as arrays

a = "python"
print(type(a))
# Out:
# <class 'str'>

# %%
print(a[0]) # position 0 is always for the first letter in the word
# Out:
# p

# %%
# how to print letter 'o'
print(a[4])
# Out:
# o

# %%
b = "coding language"
print(b[7])
# Out:
# l

# %%
print(len(a))
# Out:
# 6

# %%
print(len(b))
# Out:
# 15
